# %% [markdown]
# ### **1. Problem statement**
#  - We are given Netflix stock price from 2016 to 2021.
#  - The task is to predict the trend of the stock price for 2022 -**2023**.

# %% [markdown]
# ### **2. Import library**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import matplotlib.dates as mdates
import datetime as dt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
import plotly.express as px
from plotly import graph_objs as go

# %% [markdown]
# ### **3. Data processing**

# %% [markdown]
# #### 3.0 import the data

# %%
dataset_train = pd.read_csv('BX_train.csv')

# %%
dataset_train.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2016-01-04  28.629999  29.150000  28.270000  28.950001  20.026834  6938500
# 1  2016-01-05  29.040001  29.049999  27.920000  28.139999  19.466507  6048200
# 2  2016-01-06  27.520000  27.530001  26.950001  27.290001  18.878500  7954000
# 3  2016-01-07  26.680000  27.110001  26.320000  26.379999  18.248980  7027400
# 4  2016-01-08  26.610001  26.809999  25.459999  25.500000  17.640223  6510600

# %%
dataset_train.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1505  2021-12-23  130.820007  135.500000  130.369995  135.000000  129.022964
# 1506  2021-12-27  134.750000  135.479996  133.440002  135.100006  129.118530
# 1507  2021-12-28  135.139999  136.460007  131.350006  131.380005  125.563232
# 1508  2021-12-29  131.309998  131.490005  127.900002  128.509995  122.820290
# 1509  2021-12-30  128.610001  130.440002  128.309998  128.500000  122.810730
#
#        Volume
# 1505  4729500
# 1506  2558200
# 1507  2745400
# 1508  4076500
# 1509  2164800

# %%
training_set = dataset_train.iloc[:, 1: 2].values
training_set.shape
# Out:
# (1510, 1)

# %%
x_dates =  [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in dataset_train['Date']]

fig = px.line(x=x_dates, y=dataset_train['Open'], labels={"x":"Time Scale", "y":"Currency in USD "},title='Real Stock Price of NETFLIX.INC',width=1200,height=600)
fig.show()

# %% [markdown]
# #### 3.1 Feature scaling

# %%
sc = StandardScaler()
#fit: get min/max of train data
training_set_scaled = sc.fit_transform(training_set)
training_set_scaled.shape
# Out:
# (1510, 1)

# %% [markdown]
# #### 3.2 Data structure creation

# %% [markdown]
# - taking the reference of past 2 days of data to predict the future stock price.
# - It is observed that taking 2 days of past data gives us best results.
# - X train will have data of 2 days prior to our date and y train will have data of one day after our date

# %%
## 20 timesteps and 1 output
X_train = []
y_train = []
n_future = 1   # Number of days we want to look into the future based on the past days.
n_past = 5 # Number of past days we want to use to predict the future.



for i in range(n_past, len(training_set_scaled)- n_future +1):
    X_train.append(training_set_scaled[i-n_past: i, 0:training_set_scaled.shape[1]])
    y_train.append(training_set_scaled[i+ n_future - 1:i + n_future, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (1505, 5, 1)

# %%
y_train.shape
# Out:
# (1505, 1)

# %% [markdown]
# #### 3.3 Data reshaping

# %%
X_train = np.reshape(X_train, newshape = 
                     (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# 1. Number of stock prices - 1508
# 2. Number of time steps - 5
# 3. Number of Indicator - 1

# %%
X_train.shape
# Out:
# (1505, 5, 1)

# %% [markdown]
# ### **4. Model Building**

# %% [markdown]
# #### 4.1 Create model

# %%
model = Sequential()
# add 1st lstm layer
model.add(LSTM(units = 75, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(rate = 0.2))

# add 2nd lstm layer: 32 neurons
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(rate = 0.2))

model.add(LSTM(units = 32, return_sequences = False))
model.add(Dropout(rate = 0.2))
 
# add output layer
model.add(Dense(units = 1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 75)             23100
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 75)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 50)             25200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 50)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                10624
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 58,957
# Trainable params: 58,957
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# #### 4.2 Model fit

# %%
history = model.fit(X_train, y_train,  epochs=100, batch_size=16, verbose=1)
# Out:
# Epoch 1/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.1702
# Epoch 2/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0305
# Epoch 3/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0229
# Epoch 4/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0219
# Epoch 5/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0252
# Epoch 6/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0191
# Epoch 7/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0174
# Epoch 8/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0177
# Epoch 9/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0180
# Epoch 10/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0187
# Epoch 11/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0179
# Epoch 12/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0183
# Epoch 13/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0181
# Epoch 14/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0191
# Epoch 15/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0172
# Epoch 16/100
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0161
# Epoch 17/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0186
# Epoch 18/100
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0158
# Epoch 19/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0159
# Epoch 20/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0195
# Epoch 21/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0195
# Epoch 22/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0203
# Epoch 23/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0189
# Epoch 24/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0160
# Epoch 25/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0157
# Epoch 26/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0165
# Epoch 27/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0161
# Epoch 28/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0183
# Epoch 29/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0173
# Epoch 30/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0137
# Epoch 31/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0200
# Epoch 32/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0161
# Epoch 33/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0179
# Epoch 34/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0137
# Epoch 35/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0173
# Epoch 36/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0160
# Epoch 37/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0129
# Epoch 38/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0206
# Epoch 39/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0175
# Epoch 40/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0145
# Epoch 41/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0152
# Epoch 42/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0158
# Epoch 43/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0147
# Epoch 44/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0179
# Epoch 45/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0160
# Epoch 46/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0198
# Epoch 47/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0143
# Epoch 48/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0176
# Epoch 49/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0155
# Epoch 50/100
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0138
# Epoch 51/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0144
# Epoch 52/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0166
# Epoch 53/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0161
# Epoch 54/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0135
# Epoch 55/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0158
# Epoch 56/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0146
# Epoch 57/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0141
# Epoch 58/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0164
# Epoch 59/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0181
# Epoch 60/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0162
# Epoch 61/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0139
# Epoch 62/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.0161
# Epoch 63/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0156
# Epoch 64/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0162
# Epoch 65/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0147
# Epoch 66/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0160
# Epoch 67/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0121
# Epoch 68/100
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0180
# Epoch 69/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0149
# Epoch 70/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0165
# Epoch 71/100
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0149
# Epoch 72/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0162
# Epoch 73/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0151
# Epoch 74/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0164
# Epoch 75/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0163
# Epoch 76/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0153
# Epoch 77/100
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0123
# Epoch 78/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0136
# Epoch 79/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.0133
# Epoch 80/100
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0136
# Epoch 81/100
# 95/95 [==============================] - 2s 19ms/step - loss: 0.0155
# Epoch 82/100
# 95/95 [==============================] - 2s 18ms/step - loss: 0.0140
# Epoch 83/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0140
# Epoch 84/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0153
# Epoch 85/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0142
# Epoch 86/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0145
# Epoch 87/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0165
# Epoch 88/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0156
# Epoch 89/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0149
# Epoch 90/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0164: 0s -
# Epoch 91/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0174
# Epoch 92/100
# 95/95 [==============================] - 2s 18ms/step - loss: 0.0147
# Epoch 93/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0110
# Epoch 94/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0131
# Epoch 95/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0134
# Epoch 96/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0175: 0s - loss: 0
# Epoch 97/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0136
# Epoch 98/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0166
# Epoch 99/100
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0149
# Epoch 100/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.0163

# %% [markdown]
# ###**5. Model evaluation**

# %% [markdown]
# #### 5.1 Read and convert

# %%
dataset_test = pd.read_csv('BX_test.csv')

# %%
dataset_test.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-01-03  130.000000  130.250000  125.910004  126.629997  121.023514
# 1  2022-01-04  127.610001  127.629997  123.800003  124.940002  119.408356
# 2  2022-01-05  124.650002  124.889999  117.250000  117.790001  112.574905
# 3  2022-01-06  116.680000  119.989998  115.540001  119.160004  113.884254
# 4  2022-01-07  118.830002  119.989998  116.349998  116.650002  111.485374
#
#     Volume
# 0  3901500
# 1  3769400
# 2  6376600
# 3  4678300
# 4  2963200

# %%
dataset_test.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 204  2022-10-25  86.300003  91.599998  86.260002  91.550003  90.668304
# 205  2022-10-26  90.510002  94.110001  90.160004  92.739998  91.846840
# 206  2022-10-27  94.000000  95.260002  92.680000  93.449997  92.549995
# 207  2022-10-28  90.519997  94.379997  88.389999  93.180000  93.180000
# 208  2022-10-31  92.220001  93.070000  91.129997  91.139999  91.139999
#
#       Volume
# 204  5260100
# 205  4396000
# 206  4348600
# 207  5431300
# 208  3515400

# %%
real_stock_price = dataset_test.iloc[:, 1: 2].values
real_stock_price.shape
# Out:
# (209, 1)

# %% [markdown]
# #### 5.2 Concat and convert

# %%
#vertical concat use 0, horizontal uses 1
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), 
                          axis = 0)
#use .values to make numpy array
inputs = dataset_total[len(dataset_total) - len(dataset_test) - n_past:].values

# %% [markdown]
# #### 5.3 Reshape and scale

# %%
#reshape data to only have 1 col
inputs = inputs.reshape(-1, 1)

#scale input
inputs = sc.transform(inputs)

# %%
len(inputs)
# Out:
# 214

# %% [markdown]
# #### 5.4 Create test data strucutre

# %%
X_test = []
for i in range(n_past, len(inputs)):
    X_test.append(inputs[i-n_past:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
X_test.shape
# Out:
# (209, 5, 1)

# %% [markdown]
# ### **6. Model prediction**

# %%
predicted_stock_price = model.predict(X_test)

# %%
predicted_stock_price[:5]
# Out:
# array([[2.9419563],
#        [2.9374325],
#        [2.8745406],
#        [2.8079495],
#        [2.650269 ]], dtype=float32)

# %%
#inverse the scaled value
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %% [markdown]
# #### 6.1 Result visualization

# %%
data = {"Real_Price":real_stock_price[:,0],"Predicted_Price":predicted_stock_price[:,0]}

# %%
predicted_stock_price.shape,real_stock_price.shape
# Out:
# ((209, 1), (209, 1))

# %%
df = pd.DataFrame(data,index=dataset_test['Date'])
df.head(10)
# Out:
#             Real_Price  Predicted_Price
# Date
# 2022-01-03  130.000000       130.980270
# 2022-01-04  127.610001       130.853760
# 2022-01-05  124.650002       129.095093
# 2022-01-06  116.680000       127.232986
# 2022-01-07  118.830002       122.823708
# 2022-01-10  115.680000       121.850716
# 2022-01-11  115.769997       118.695900
# 2022-01-12  122.169998       117.453545
# 2022-01-13  122.610001       119.865669
# 2022-01-14  116.070000       120.805946

# %%
#fig = px.line(df,x=df.index, y=["Real_Price","Predicted_Price"],labels={"x":"Time Scale", "y":"Currency in USD "},title='Real Stock Price Vs Predicted Stock Price of NETFLIX.INC',width=1200,height=600)
#fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df.index, y=df["Real_Price"], name="Real Stock Price"))
fig.add_trace(go.Scatter(x=df.index, y=df["Predicted_Price"], name="Predicted Stock Price"))
fig.layout.update(title_text='Real Stock Price Vs Predicted Stock Price of NETFLIX.INC', xaxis_rangeslider_visible=True)
fig.show()

# %%
rmse=np.sqrt(np.mean(((predicted_stock_price- real_stock_price)**2)))
rmse
# Out:
# 4.39673867148788

# %% [markdown]
# ###**7. Model Forecasting**

# %%
train_dates = pd.to_datetime(dataset_test['Date'])

# %%
n_future = 200
forecast_period_dates = pd.date_range(list(train_dates)[-1],periods=n_future,freq='1d').tolist()
forecast = model.predict(X_test[-n_future:])

# %%
forecast_copies = np.repeat(forecast, dataset_test.shape[1], axis=-1)
y_pred_future = sc.inverse_transform(forecast_copies)[:,0]

# %%
forecast_dates = []
for time_i in forecast_period_dates:
    forecast_dates.append(time_i.date())

# %%
original = dataset_test[['Date', 'Open']]
original
# Out:
#            Date        Open
# 0    2022-01-03  130.000000
# 1    2022-01-04  127.610001
# 2    2022-01-05  124.650002
# 3    2022-01-06  116.680000
# 4    2022-01-07  118.830002
# ..          ...         ...
# 204  2022-10-25   86.300003
# 205  2022-10-26   90.510002
# 206  2022-10-27   94.000000
# 207  2022-10-28   90.519997
# 208  2022-10-31   92.220001
#
# [209 rows x 2 columns]

# %%
df_forecast = pd.DataFrame({'Forecast_Date':np.array(forecast_dates), 'Forecast_Price':y_pred_future})
df_forecast["Forecast_Price"].iloc[0]=original["Open"].iloc[-1]
df_forecast[1:]
# Out:
# c:\Users\dell\anaconda3\envs\ml\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Forecast_Date  Forecast_Price
# 1      2022-11-01      118.820183
# 2      2022-11-02      117.772255
# 3      2022-11-03      117.386505
# 4      2022-11-04      115.488480
# 5      2022-11-05      113.134460
# ..            ...             ...
# 195    2023-05-14       86.489021
# 196    2023-05-15       86.211281
# 197    2023-05-16       88.095261
# 198    2023-05-17       90.640541
# 199    2023-05-18       90.450157
#
# [199 rows x 2 columns]

# %%
fig = px.line(df_forecast[1:],x='Forecast_Date', y='Forecast_Price',labels={"x":"Time Scale", "y":"Currency in USD "},title='Forecasted Stock Price of NETFLIX.INC',width=1200,height=600)
fig.show()

# %%
print(df_forecast[df_forecast.Forecast_Price == df_forecast.Forecast_Price.max()]) #Maximum expected stock price value of Netflix
# Out:
#    Forecast_Date  Forecast_Price
# 15    2022-11-15      133.072205

# %%
# fig = go.Figure()
# fig.add_trace(go.Scatter(x=original['Date'], y=original['Open'], name="Past Stock"))
# fig.add_trace(go.Scatter(x=df_forecast['Forecast_Date'], y=df_forecast['Forecast_Price'], name="Forecasted Stock"))
# fig.layout.update(title_text='Stock Price of NETFLIX.INC', xaxis_rangeslider_visible=True)
# fig.show()
